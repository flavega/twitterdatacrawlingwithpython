# %% [markdown]
# # SENTIMENT ANALYSIS TWITTER INVESTASI

# %%
import tweepy
from textblob import TextBlob
import pandas as pd 
import numpy as np
import csv
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
consumer_key = 'aW6bZeLDepxxeuRIa4NrHugUW'
consumer_key_secret = 'Sfo3aOeV7NB26dcEZhRviI7xYop5pxPYQF4eBfppCZaebe0ZZh'
access_token = '1541429509827678208-52LqM004qft1RGUnJghAFskWvEEo2z'
access_token_secret = 'hVNVoZls06SPehqQgUOwPBQKDKfw7RcGdF0JskrEcyTcu'

# %%
auth = tweepy.OAuthHandler(consumer_key,consumer_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
search_term = 'Saham -filter:replies AND -filter:retweets'
tweets = tweepy.Cursor(api.search_tweets, q=search_term, lang='id', since_id='2022-08-06', tweet_mode='extended').items(2000)
all_tweets = [tweet.full_text for tweet in tweets]

# %%
csvFile = open(search_term+".csv","a+",newline="",encoding="utf-8")
csvWriter = csv.writer(csvFile)
c = []
i = []
u = []
t = []

for tweet in tweepy.Cursor(api.search_tweets,q=search_term,count=2000,lang="id",since_id="2022-08-06",tweet_mode='extended').items():
    print(tweet.created_at,tweet.id,tweet.user.name,tweet.full_text)
    c.append(tweet.created_at)
    i.append(tweet.id)
    u.append(tweet.user.name)
    t.append(tweet.full_text.encode("utf-8"))
    tweets = [tweet.created_at,tweet.id,tweet.user.name,tweet.full_text.encode("utf-8")]
    csvWriter.writerow(tweets)

dictTweets = {'waktu':c,'id':i,'username':u,'teks':t}
df = pd.DataFrame(dictTweets,columns=['waktu','id','username','teks'])
df
# Out:
# 2022-08-15 15:18:23+00:00 1559197818946203648 Tribun Jatim Sinopsis Drama Korea Stock Struck, Kisahkan Soal Investasi Saham, Gaet Han Ji Eun Tokoh Utamanya
#
# https://t.co/syC06uzXjf via @tribunjatim
# 2022-08-15 15:10:06+00:00 1559195737128583168 paijo mawon 🐓 Waaa keren diam² @NUgarislucu jg punya saham di RANS https://t.co/m1V376uOVE
# 2022-08-15 15:05:56+00:00 1559194686467837952 sekolahsaham.com Sempunakan Diri, Bukan Indikator https://t.co/e2LFUYJncF
# 2022-08-15 15:04:12+00:00 1559194252822794240 Bisnis.com Lo Kheng Hong Borong Saham Intiland DILD https://t.co/zpdTPImSCs
# 2022-08-15 15:00:24+00:00 1559193296462680064 Fiffy Lain org lain rezeki. Ad org rezeki kwin awl, dpt anak.. dia dh ada saham akhirat yg akan doakan dia ktika dia mati. Meanwhile org yg msih mmbujang mgkin ad rezeki utk brbakti kpd ibu bapa n tlg adik beradik. Nasib and dugaan org lain2. Tuhan uji yg sewajarnya pd kita. https://t.co/pbICXAVY16
# ...

# %%
df = pd.DataFrame(all_tweets, columns=['Tweets'])
df.head(1000)
# Out:
#                                                 Tweets
# 0    Investasi Kuliner Legendaris Martabak LEGIT Gr...
# 1    Investasi di saham, investasi di figure juga.....
# 2    investasi ini yang bakalan bisa menjamin masa ...
# 3    Persiapkan dana darurat untuk kejadian tak ter...
# 4    Selamat Malam Karangasem ,\nApakah kamu punya ...
# ..                                                 ...
# 995  Jangan asal percaya. Banyak lho tawaran bisnis...
# 996  Paling Perkasa di Asia,Rupiah Spot Ditutup Men...
# 997  Elon Musk Menjual Saham Tesla Senilai Hampir $...
# 998  Jual l Beli | Sewa | Investasi\nKe ERA Bandung...
# 999  Sepertinya era mobil listrik bisa bikin merek ...
#
# [1000 rows x 1 columns]

# %%
def cleanTwt(twt)
# Out:
#   Input In [11]
#     def cleanTwt(twt)
#                      ^
# SyntaxError: invalid syntax
